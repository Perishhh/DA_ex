# %%
import pandas as pd
import numpy as np

# %%
summer_df = pd.read_csv("load_summer.csv")
summer_df.head(5)
# Out:
#          COAST  temp  weekday    date  hour
# 0  10859.02310  23.1        1  6/1/10     9
# 1  11750.15184  23.1        1  6/1/10    10
# 2  12645.00556  23.1        1  6/1/10    11
# 3  13422.53047  26.1        1  6/1/10    12
# 4  14135.83310  27.1        1  6/1/10    13

# %%
summer_df['COAST'].describe()
# Out:
# count     5820.000000
# mean     14834.326813
# std       2120.928312
# min       9276.922926
# 25%      13148.745592
# 50%      15059.883320
# 75%      16529.613120
# max      19928.724770
# Name: COAST, dtype: float64

# %%
summer_df.hist('COAST', bins = 100)
# Out:
# array([[<AxesSubplot: title={'center': 'COAST'}>]], dtype=object)

# %%
coast_per_hour = summer_df.groupby('hour')['COAST'].mean()
print(coast_per_hour)
coast_per_hour.plot.line()
# Out:
# hour
# 9     11652.704393
# 10    12607.869052
# 11    13597.006934
# 12    14481.301405
# 13    15178.029117
# 14    15748.938608
# 15    16149.174541
# 16    16369.773180
# 17    16392.104322
# 18    16166.366575
# Name: COAST, dtype: float64
# <AxesSubplot: xlabel='hour'>
